# %%
data()

# %%
ilinet <- read.csv("ILINet.csv", header=T, skip = 1)
head(ilinet)
# Out:
#   REGION.TYPE REGION YEAR WEEK X..WEIGHTED.ILI X.UNWEIGHTED.ILI AGE.0.4
# 1 National    X      2018 40   1.40915         1.41965          4912
# 2 National    X      2018 41   1.39810         1.47352          5339
# 3 National    X      2018 42   1.45944         1.58658          5569
# 4 National    X      2018 43   1.64212         1.74181          6258
# 5 National    X      2018 44   1.77754         1.83999          6867
# 6 National    X      2018 45   1.86204         1.92837          7512
#   AGE.25.49 AGE.25.64 AGE.5.24 AGE.50.64 AGE.65 ILITOTAL NUM..OF.PROVIDERS
# 1 3890      X         6292     1564      1304   17962    2602
# 2 4050      X         6237     1677      1330   18633    2638
# 3 4417      X         6711     1759      1403   19859    2613
# 4 4699      X         7462     1949      1498   21866    2670
# 5 4728      X         8163     1861      1457   23076    2653
# 6 4831      X         8379     1895      1456   24073    2659
#   TOTAL.PATIENTS
# 1 1265240
# ...

# %%
wn_clinical_labs <- read.csv("WHO_NREVSS_Clinical_Labs.csv", header=T, skip = 1)
head(wn_clinical_labs)



# months <- c("Jan","Feb","Mar","Apr","May", "Jun", "Jul", "Aug", "Sep", "Oct", "Nov", "Dec")
# colors <- c("cornflower blue","Salmon")

# # sales  # to verify that data has been read

# barplot(as.matrix(as.data.frame(t(sales))),beside=T,xlab="month",names.arg=months, col=colors,axis.lty="solid")
# legend("topleft",rownames(t(sales)),fill=colors,title="Data Type")
# Out:
#   REGION.TYPE REGION YEAR WEEK TOTAL.SPECIMENS TOTAL.A TOTAL.B PERCENT.POSITIVE
# 1 National    X      2018 40   16492           218     69      1.74024
# 2 National    X      2018 41   17980           222     81      1.68521
# 3 National    X      2018 42   20128           311     89      1.98728
# 4 National    X      2018 43   21302           337     98      2.04206
# 5 National    X      2018 44   22281           389     98      2.18572
# 6 National    X      2018 45   23304           543     95      2.73773
#   PERCENT.A PERCENT.B
# 1 1.32185   0.418385
# 2 1.23471   0.450501
# 3 1.54511   0.442170
# 4 1.58201   0.460051
# 5 1.74588   0.439837
# 6 2.33007   0.407655
# Error in barplot.default(wn_clinical_labs, col = "green", xlab = "Week"): 'height' must be a vector or a matrix
# Traceback:
#
# 1. barplot(wn_clinical_labs, col = "green", xlab = "Week")
# 2. barplot.default(wn_clinical_labs, col = "green", xlab = "Week")
# 3. stop("'height' must be a vector or a matrix")

# %%
wn_pub_health_labs <- read.csv("WHO_NREVSS_Public_Health_Labs.csv", header=T, skip = 1)
head(wn_pub_health_labs)


# [6,7,8,9,10,11,12]

barplot(as.matrix(as.data.frame(t(wn_pub_health_labs[,6:12]))), beside=F, xlab="Number of positive specimen", col=rainbow(7), axis.lty="solid")
# legend("topleft",rownames(t(sales)),fill=colors,title="Data Type")
# Out:
#   REGION.TYPE REGION YEAR WEEK TOTAL.SPECIMENS A..2009.H1N1. A..H3.
# 1 National    X      2018 40    793             29           11
# 2 National    X      2018 41    898             52           11
# 3 National    X      2018 42   1086             51           21
# 4 National    X      2018 43   1089             74           35
# 5 National    X      2018 44   1217             82           23
# 6 National    X      2018 45   1306            117           27
#   A..Subtyping.not.Performed. B BVic BYam H3N2v
# 1  7                          0 7    11   0
# 2  7                          5 3     5   0
# 3 13                          1 2    14   0
# 4  3                          3 0    13   0
# 5  2                          1 1     8   0
# 6 14                          4 4     7   0
# plot without title
